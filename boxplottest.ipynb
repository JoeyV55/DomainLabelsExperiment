# %%
import pandas as pd
import matplotlib.pyplot as plt

# Sample Data
data = {'Category': ['A', 'A', 'B', 'B', 'C', 'C'],
        'Value': [10, 12, 15, 18, 20, 22]}
df = pd.DataFrame(data)

# Descriptive Statistics
desc_stats = df.groupby('Category')['Value'].describe()

# Boxplot
plt.figure(figsize=(8, 6))
df.boxplot(column='Value', by='Category')
plt.title('Boxplot of Value by Category')
plt.xlabel('Category')
plt.ylabel('Value')
plt.suptitle('')  # Remove default title
plt.show()

# Display Descriptive Statistics Table
print(desc_stats)
# Out:
#           count  mean       std   min    25%   50%    75%   max
# Category
# A           2.0  11.0  1.414214  10.0  10.50  11.0  11.50  12.0
# B           2.0  16.5  2.121320  15.0  15.75  16.5  17.25  18.0
# C           2.0  21.0  1.414214  20.0  20.50  21.0  21.50  22.0
