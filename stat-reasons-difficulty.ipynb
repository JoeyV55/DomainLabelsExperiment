# %%
import pandas as pd
from scipy.stats import chi2_contingency

# 1. Read the CSV file (adjust the file path if needed)
df = pd.read_csv("./data/qualitativo_fabio - qualitativo_fabio.csv")

# 2. Remove rows where column 'P' is empty (i.e. NaN or an empty string)
df_filtered = df[df['P'].notna() & (df['P'] != "")]

# 3. Create a contingency table of 'group' vs 'REASONS_TO_CONFIDENCE'
contingency_table = pd.crosstab(df_filtered['group'], df_filtered['REASONS FOR DIFFICULTY'])
print("Contingency Table:")
print(contingency_table)

# 4. Perform the chi-square test
chi2, p_value, dof, expected = chi2_contingency(contingency_table)

print("\nChi-Square Test Results:")
print("Chi-Square Statistic:", chi2)
print("Degrees of Freedom:", dof)
print("P-value:", p_value)
print("\nExpected Frequencies:")
print(expected)

# 5. Interpretation of the result
if p_value < 0.05:
    print("\nConclusion: Significant difference found (p < 0.05).")
else:
    print("\nConclusion: No significant difference found (p >= 0.05).")
# Out:
# Contingency Table:
# REASONS FOR DIFFICULTY  DEBUG PROCESS  FAMILIARITY WITH CODEBASE  \
# group
# Control                             0                          0
# Treatment                           2                          1
#
# REASONS FOR DIFFICULTY  FAMILIARITY WITH CODEBASE and DEBUG PROCESS  \
# group
# Control                                                           1
# Treatment                                                         0
#
# REASONS FOR DIFFICULTY  FINDING THE ISSUE IN CODE  \
# group
# Control                                         4
# Treatment                                       1
#
# REASONS FOR DIFFICULTY  FINDING THE ISSUE IN CODE and DEBUG PROCESS  \
# group
# Control                                                           1
# Treatment                                                         1
#
# REASONS FOR DIFFICULTY  ISSUE COMPLEXITY  \
# group
# Control                                0
# Treatment                              4
#
# REASONS FOR DIFFICULTY  ISSUE COMPLEXITY\nFAMILIARITY WITH CODEBASE  \
# group
# Control                                                           0
# Treatment                                                         1
#
# REASONS FOR DIFFICULTY  LACK OF CLARITY  NOT HAVING ENOUGH SKILLS  \
# group
# Control                               1                         2
# Treatment                             0                         2
#
# REASONS FOR DIFFICULTY  NOT HAVING ENOUGH SKILLS and\nFINDING THE ISSUE IN CODE
# group
# Control                                                                 0
# Treatment                                                               1
#
# Chi-Square Test Results:
# Chi-Square Statistic: 12.485470085470086
# Degrees of Freedom: 9
# P-value: 0.18730306793331122
#
# Expected Frequencies:
# [[0.81818182 0.40909091 0.40909091 2.04545455 0.81818182 1.63636364
#   0.40909091 0.40909091 1.63636364 0.40909091]
#  [1.18181818 0.59090909 0.59090909 2.95454545 1.18181818 2.36363636
#   0.59090909 0.59090909 2.36363636 0.59090909]]
#
# Conclusion: No significant difference found (p >= 0.05).

# %%
import pandas as pd
from scipy.stats import chi2_contingency

# Load the CSV file from the provided path.
# We assume the CSV file is formatted as a contingency table with row labels in the first column.
df = pd.read_csv("./data/difficulty.csv", index_col=0)
print("Contingency Table:")
print(df)

# Compute the chi-square test.
chi2, p, dof, expected = chi2_contingency(df)

print("\nChi-Square Test Results:")
print("Chi-square Statistic:", chi2)
print("Degrees of Freedom:", dof)
print("P-value:", p)
print("\nExpected Frequencies:")
print(expected)

# Interpretation based on a significance level of 0.05.
if p < 0.05:
    print("\nConclusion: Significant difference found (p < 0.05).")
else:
    print("\nConclusion: No significant difference found (p >= 0.05).")
# Out:
# Contingency Table:
#        debug  familar  find  complex  clarity  skills
# group
# c          2        1     5        0        1       0
# t          3        2     3        5        0       2
#
# Chi-Square Test Results:
# Chi-square Statistic: 8.035555555555556
# Degrees of Freedom: 5
# P-value: 0.15428694686907993
#
# Expected Frequencies:
# [[1.875 1.125 3.    1.875 0.375 0.75 ]
#  [3.125 1.875 5.    3.125 0.625 1.25 ]]
#
# Conclusion: No significant difference found (p >= 0.05).
